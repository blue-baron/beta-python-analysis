# %% [markdown]
# # ATO Community Quantitative Analysis - Comparison

# %% [markdown]
# ### Import packages

# %%
import seaborn as sns
import pandas as pd
from IPython.display import display, HTML

import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# for plotting purposes
# %matplotlib inline

# %% [markdown]
# ### Import custom functions

# %%
import loop11_functions as beta
# %run loop11_functions.py

# %% [markdown]
# ### Import cleaned data

# %%
clean_df = pd.read_csv('ato-community_full_clean.csv')
clean_df.head()
# Out:
#   Participant No.  CustomID       IP Address    Date Started  Date Completed  \
# 0  Participant 48       NaN    203.173.10.21  05/25/17 11:40  05/25/17 11:44
# 1  Participant 51       NaN  120.147.129.202  05/25/17 12:17  05/25/17 12:25
# 2  Participant 53       NaN    203.55.28.231  05/25/17 12:23  05/25/17 12:29
# 3  Participant 54       NaN     202.20.30.89  05/25/17 12:27  05/25/17 12:31
# 4  Participant 55       NaN   150.101.255.43  05/25/17 12:30  05/25/17 12:35
#
#                                           User Agent  Total Time Spent  \
# 0  Mozilla/5.0 (Windows NT 6.3; WOW64; rv:53.0) G...               223
# 1  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...               489
# 2  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:49.0) G...               351
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3...               254
# 4  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...               265
#
#    Avg Time Taken  Avg Page Views Task. How to use this panel - Completion  \
# 0            20.5             1.5                                  success
# 1            54.5             1.5                                  success
# 2            39.0             1.5                                  success
# 3            52.5             2.0                                  success
# 4            54.0             1.5                                  success
#
#                  ...                 \
# 0                ...
# 1                ...
# 2                ...
# 3                ...
# 4                ...
#
#    * "I would consider ATO Community a reliable source of information."  \
# 0                          Neither agree no disagree
# 1                          Neither agree no disagree
# 2                                              Agree
# 3                          Neither agree no disagree
# 4                                              Agree
#
#    * How would you expect to hear about ATO Community?  \
# 0  ATO Social media, Email from ATO, Television, ...
# 1                                     Email from ATO
# 2      ATO Social media, Email from ATO, ATO website
# 3               ATO website, Small Business Newsroom
# 4                                        ATO website
#
#   * How would you expect to hear about ATO Community? - Other, please specify  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    * "I would contact the ATO after using ATO Community to make sure the information I found is correct."  \
# 0                                     Strongly agree
# 1                                              Agree
# 2                                              Agree
# 3                         Neither agree nor disagree
# 4                                           Disagree
#
#    * What three words describe your experience today with ATO Community?  \
# 0                     informative, precise and clear
# 1                           Not necessarily reliable
# 2                                 nice, good, thanks
# 3                                         Looks good
# 4                                        Easy to use
#
#   Do you have any suggestions on how we can improve ATO Community?  \
# 0                                                NaN
# 1                                                NaN
# 2  Looks nice, I like how its setup right now, ve...
# 3                                                NaN
# 4                                                NaN
#
#   * Which of the following best describes your role? (Select all that apply)  \
# 0                                     Small business
# 1                                   Tax professional
# 2                                         Individual
# 3                                     Small business
# 4                                   Tax professional
#
#   * Which of the following best describes your role? - Other, please specify  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   * Are you an ATO employee? Which age group do you belong to?
# 0                         No                     Older than 65
# 1                         No                     Older than 65
# 2                         No                             26-35
# 3                         No                             46-65
# 4                         No                             46-65
#
# [5 rows x 32 columns]

# %%
N = len(clean_df)
N
# Out:
# 196

# %%
# Delare variable to store folder file location
folder = "Graphs/comparison_graphs/"

# %%
list(clean_df.columns.values) # For reference later when picking out data in specific column
# Out:
# ['Participant No.',
#  'CustomID',
#  'IP Address',
#  'Date Started',
#  'Date Completed',
#  'User Agent',
#  'Total Time Spent',
#  'Avg Time Taken',
#  'Avg Page Views',
#  'Task. How to use this panel - Completion',
#  'Task. How to use this panel - Page Views',
#  'Task. How to use this panel - Time Spent',
#  'Task 1 - ATO-certified answer - Completion',
#  'Task 1 - ATO-certified answer - Page Views',
#  'Task 1 - ATO-certified answer - Time Spent',
#  '* How regularly do you use online forums?',
#  '* How would you know if an answer is the official response?',
#  '* "I found it easy to find information to complete the task."',
#  '* "I would trust an \'ATO certified\' answer."',
#  '* "I would trust an answer from an ATO Community member."',
#  '* How likely are you to use ATO Community in the future? (1 = least likely, 10 = most likely)',
#  '* How likely are you to recommend ATO Community to others? (1 = least likely, 10 = most likely)',
#  '* "I would consider ATO Community a reliable source of information."',
#  '* How would you expect to hear about ATO Community?',
#  '* How would you expect to hear about ATO Community? - Other, please specify',
#  '* "I would contact the ATO after using ATO Community to make sure the information I found is correct."',
#  '* What three words describe your experience today with ATO Community?',
#  'Do you have any suggestions on how we can improve ATO Community?',
#  '* Which of the following best describes your role? (Select all that apply)',
#  '* Which of the following best describes your role? - Other, please specify',
#  '* Are you an ATO employee?',
#  'Which age group do you belong to?']

# %% [markdown]
# ## Compare task to questions

# %% [markdown]
# ### Task 1 - ATO-certified answer VS How regularly do you use online forums?

# %%
beta.compare_task_VS_single(clean_df, 'Task 1 - ATO-certified answer - Completion', 
                       '* How regularly do you use online forums?', folder)
# Out:
#                                                                                               (N)  \
# Task 1 - ATO-certified answer - Completion : Re... * How regularly do you use online forums?
# success                                            Yearly                                      10
#                                                    Weekly                                      21
#                                                    Never                                       13
#                                                    Monthly                                     30
#                                                    Daily                                       16
# fail                                               Yearly                                       9
#                                                    Weekly                                      29
#                                                    Never                                       22
#                                                    Monthly                                     23
#                                                    Daily                                       14
# abandon                                            Yearly                                       1
#                                                    Never                                        5
#                                                    Monthly                                      2
#                                                    Daily                                        1
#
#                                                                                                    (%)
# Task 1 - ATO-certified answer - Completion : Re... * How regularly do you use online forums?
# success                                            Yearly                                     0.111111
#                                                    Weekly                                     0.233333
#                                                    Never                                      0.144444
#                                                    Monthly                                    0.333333
#                                                    Daily                                      0.177778
# fail                                               Yearly                                     0.092784
#                                                    Weekly                                     0.298969
#                                                    Never                                      0.226804
#                                                    Monthly                                    0.237113
#                                                    Daily                                      0.144330
# abandon                                            Yearly                                     0.111111
#                                                    Never                                      0.555556
#                                                    Monthly                                    0.222222
#                                                    Daily                                      0.111111

# %% [markdown]
# ###  Task 1 - ATO-certified answer VS I found it easy to find information to complete the task.

# %%
scale = {'Strongly disagree': 'Disagree', 'Strongly agree': 'Agree'}
beta.compare_task_VS_likert(clean_df, 'Task 1 - ATO-certified answer - Completion',
                       '* "I found it easy to find information to complete the task."', folder, scale)
# Out:
#                                                                                                        (N)  \
# Task 1 - ATO-certified answer - Completion : Re... * "I found it easy to find information to compl...
# success                                            Neither agree nor disagree                            5
#                                                    Disagree                                              4
#                                                    Agree                                                81
# fail                                               Neither agree nor disagree                           26
#                                                    Disagree                                             11
#                                                    Agree                                                59
# abandon                                            Neither agree nor disagree                            3
#                                                    Disagree                                              5
#                                                    Agree                                                 1
#
#                                                                                                             (%)
# Task 1 - ATO-certified answer - Completion : Re... * "I found it easy to find information to compl...
# success                                            Neither agree nor disagree                          0.055556
#                                                    Disagree                                            0.044444
#                                                    Agree                                               0.900000
# fail                                               Neither agree nor disagree                          0.270833
#                                                    Disagree                                            0.114583
#                                                    Agree                                               0.614583
# abandon                                            Neither agree nor disagree                          0.333333
#                                                    Disagree                                            0.555556
#                                                    Agree                                               0.111111

# %% [markdown]
# ### Task 1 VS I would trust an ATO certified answer

# %%
beta.compare_task_VS_likert(clean_df, 'Task 1 - ATO-certified answer - Completion',
                       '* "I would trust an \'ATO certified\' answer."', folder, scale)
# Out:
#                                                                                                  (N)  \
# Task 1 - ATO-certified answer - Completion : Re... * "I would trust an 'ATO certified' answer."
# success                                            Neither agree nor disagree                      4
#                                                    Disagree                                        3
#                                                    Agree                                          82
# fail                                               Neither agree nor disagree                     12
#                                                    Disagree                                        7
#                                                    Agree                                          78
# abandon                                            Neither agree nor disagree                      2
#                                                    Disagree                                        1
#                                                    Agree                                           6
#
#                                                                                                       (%)
# Task 1 - ATO-certified answer - Completion : Re... * "I would trust an 'ATO certified' answer."
# success                                            Neither agree nor disagree                    0.044944
#                                                    Disagree                                      0.033708
#                                                    Agree                                         0.921348
# fail                                               Neither agree nor disagree                    0.123711
#                                                    Disagree                                      0.072165
#                                                    Agree                                         0.804124
# abandon                                            Neither agree nor disagree                    0.222222
#                                                    Disagree                                      0.111111
#                                                    Agree                                         0.666667

# %% [markdown]
# ### Task 1 - ATO-certified answer VS I would trust an answer from an ATO Community member

# %%
beta.compare_task_VS_likert(clean_df, 'Task 1 - ATO-certified answer - Completion',
                       '* "I would trust an answer from an ATO Community member."', folder, scale)
# Out:
#                                                                                                        (N)  \
# Task 1 - ATO-certified answer - Completion : Re... * "I would trust an answer from an ATO Communit...
# success                                            Neither agree nor disagree                           51
#                                                    Disagree                                             28
#                                                    Agree                                                11
# fail                                               Neither agree nor disagree                           54
#                                                    Disagree                                             32
#                                                    Agree                                                11
# abandon                                            Neither agree nor disagree                            4
#                                                    Disagree                                              4
#                                                    Agree                                                 1
#
#                                                                                                             (%)
# Task 1 - ATO-certified answer - Completion : Re... * "I would trust an answer from an ATO Communit...
# success                                            Neither agree nor disagree                          0.566667
#                                                    Disagree                                            0.311111
#                                                    Agree                                               0.122222
# fail                                               Neither agree nor disagree                          0.556701
#                                                    Disagree                                            0.329897
#                                                    Agree                                               0.113402
# abandon                                            Neither agree nor disagree                          0.444444
#                                                    Disagree                                            0.444444
#                                                    Agree                                               0.111111

# %% [markdown]
# ### Task 1 - ATO-certified answer VS I would consider ATO Community a reliable source of information

# %%
beta.compare_task_VS_likert(clean_df, 'Task 1 - ATO-certified answer - Completion',
                      '* "I would consider ATO Community a reliable source of information."', folder, scale)
# Out:
#                                                                                                        (N)  \
# Task 1 - ATO-certified answer - Completion : Re... * "I would consider ATO Community a reliable so...
# success                                            Neither agree no disagree                            32
#                                                    Disagree                                              3
#                                                    Agree                                                55
# fail                                               Neither agree no disagree                            41
#                                                    Disagree                                             12
#                                                    Agree                                                44
# abandon                                            Neither agree no disagree                             4
#                                                    Disagree                                              3
#                                                    Agree                                                 2
#
#                                                                                                             (%)
# Task 1 - ATO-certified answer - Completion : Re... * "I would consider ATO Community a reliable so...
# success                                            Neither agree no disagree                           0.355556
#                                                    Disagree                                            0.033333
#                                                    Agree                                               0.611111
# fail                                               Neither agree no disagree                           0.422680
#                                                    Disagree                                            0.123711
#                                                    Agree                                               0.453608
# abandon                                            Neither agree no disagree                           0.444444
#                                                    Disagree                                            0.333333
#                                                    Agree                                               0.222222

# %% [markdown]
# ### Task 1 - ATO-certified answer VS I would contact the ATO after using ATO Community to make sure the information I found is correct

# %%
beta.compare_task_VS_likert(clean_df, 'Task 1 - ATO-certified answer - Completion',
                      '* "I would contact the ATO after using ATO Community to make sure the information I found is correct."', folder, scale)
# Out:
#                                                                                                        (N)  \
# Task 1 - ATO-certified answer - Completion : Re... * "I would contact the ATO after using ATO Comm...
# success                                            Neither agree nor disagree                           26
#                                                    Disagree                                             42
#                                                    Agree                                                22
# fail                                               Neither agree nor disagree                           33
#                                                    Disagree                                             18
#                                                    Agree                                                46
# abandon                                            Neither agree nor disagree                            2
#                                                    Disagree                                              1
#                                                    Agree                                                 6
#
#                                                                                                             (%)
# Task 1 - ATO-certified answer - Completion : Re... * "I would contact the ATO after using ATO Comm...
# success                                            Neither agree nor disagree                          0.288889
#                                                    Disagree                                            0.466667
#                                                    Agree                                               0.244444
# fail                                               Neither agree nor disagree                          0.340206
#                                                    Disagree                                            0.185567
#                                                    Agree                                               0.474227
# abandon                                            Neither agree nor disagree                          0.222222
#                                                    Disagree                                            0.111111
#                                                    Agree                                               0.666667
