# %% [markdown]
# #### Import packages.

# %%
import pandas as pd
from IPython.display import display, HTML

# %% [markdown]
# #### Import raw data csv from Lithium.

# %%
# Create variable and create DataFrame from the raw data exported from testing tool.
# Skip the top 3 lines 
raw_df = pd.read_csv('LSI-2017-1805-1206.csv', encoding = 'latin1')
display(raw_df)
# Out:
#    Question 1 What was the purpose of your visit to the ATO Community? Question 2 Were you able to find what you were looking for? Question 3 [If answered Yes for Q2 ] If your visit had not been successful, what would you have done next? Question 4 If answered No for Q2] Since you didn't find what you were looking for, what are you going to do next?   Question 5 How would you rate your overall experience on ATO Community?                                   Any other feedback?
# 0                                              search                                                                  no                                                         NaN                                                                                                         Call                                                                                                                    3                                                                         NaN
# 1                                       Find out more                                                                 yes                                                         Ask                                                                                                          NaN                                                                                                                    1                           If this were to be rolled out by the ATO into ...
# 2                                       Find out more                                                                 yes                                                         Ask                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 3                                                 Ask                                                                  no                                                         NaN                                                                                                          Ask                                                                                                                    2                                                                         NaN
# 4                                       Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    3                                                                         NaN
# 5                                                 Ask                                                                 yes                                                        Call                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 6                                       Find out more                                                                  no                                                         NaN                                                                                                        Other                                                                                                                    5                           I agree with one of the other posters - How ca...
# 7                                       Find out more                                                                  no                                                         NaN                                                                                                   ato.gov.au                                                                                                                    2                                                                         NaN
# 8                                               Other                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 9                                       Find out more                                                                 yes                                                         Ask                                                                                                          NaN                                                                                                                    3                           I regard this as a great concept.  Being invol...
# 10                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    2                                                                          no
# 11                                             search                                                                  no                                                         NaN                                                                                                   ato.gov.au                                                                                                                    3                                                                         NaN
# 12                                                Ask                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 13                                      Find out more                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    2                                                                          No
# 14                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    3                                                                         NaN
# 15                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 16                                      Find out more                                                                 yes                                                         Ask                                                                                                          NaN                                                                                                                    1                           Looking forward to seeing more community membe...
# 17                                             search                                                                 yes                                                        Call                                                                                                          NaN                                                                                                                    2                                                          none at the moment
# 18                                      Find out more                                                                  no                                                         NaN                                                                                                   ato.gov.au                                                                                                                    3                           this type of general information information d...
# 19                                              Other                                                                  no                                                         NaN                                                                                                        Other                                                                                                                    3                                                                         UFN
# 20                                      Find out more                                                                 yes                                                         Ask                                                                                                          NaN                                                                                                                    3                                                                         NaN
# 21                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    1                                         No. I have no other feedback ideas.
# 22                                      Find out more                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    3                                                                         NaN
# 23                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    2                                                                   All good
# 24                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    3                                                           not at the moment
# 25                                             search                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 26                                      Find out more                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    3                                       first  time  that  i  have  connected
# 27                                      Find out more                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    3                                                                          No
# 28                                      Find out more                                                                  no                                                         NaN                                                                                                   ato.gov.au                                                                                                                    3                                                                         NaN
# 29                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    3                                                                         NaN
# ..                                                ...                                                                 ...                                                         ...                                                                                                          ...                                                                                                                  ...                                                                         ...
# 60                                             search                                                                  no                                                         NaN                                                                                                         Call                                                                                                                    4                                                                         NaN
# 61                                              Other                                                                 yes                                                         Ask                                                                                                          NaN                                                                                                                    1                                                                         NaN
# 62                                             search                                                                  no                                                         NaN                                                                                                   ato.gov.au                                                                                                                    3                                                                         NaN
# 63                                        Participate                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    3                           Are people able to rely on advice given in thi...
# 64                                      Find out more                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 65                                      Find out more                                                                 yes                                                         Ask                                                                                                          NaN                                                                                                                    2                                                                          No
# 66                                      Find out more                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    3                                                                         NaN
# 67                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    3                                                                          no
# 68                                             search                                                                  no                                                         NaN                                                                                                         Alex                                                                                                                    3                                                                         NaN
# 69                                              Other                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 70                                      Find out more                                                                  no                                                         NaN                                                                                                        Other                                                                                                                    1                           I don't understand the credentials behind ATO ...
# 71                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 72                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 73                                      Find out more                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 74                                              Other                                                                 yes                                                        Call                                                                                                          NaN                                                                                                                    3                                                                         NaN
# 75                                              Other                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    3                           If the Community includes official responses f...
# 76                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    3                                                                         NaN
# 77                                              Other                                                                 yes                                                        Call                                                                                                          NaN                                                                                                                    2                           Why don't you use Qualtrics to do your researc...
# 78                                              Other                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    1                                                                         NaN
# 79                                              Other                                                                 yes                                                         Ask                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 80                                             search                                                                  no                                                         NaN                                                                                                   ato.gov.au                                                                                                                    4                                                                         NaN
# 81                                      Find out more                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    3                                                                         NaN
# 82                                      Find out more                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    1                                                                         NaN
# 83                                              Other                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    3                                                                         NaN
# 84                                              Other                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 85                                              Other                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    2                                                                         NaN
# 86                                                Ask                                                                  no                                                         NaN                                                                                                          Ask                                                                                                                    2                                                                         NaN
# 87                                             search                                                                 yes                                                        Call                                                                                                          NaN                                                                                                                    1                           Fix it so this survey doesn't come up on top o...
# 88                                        Participate                                                                 yes                                                       Other                                                                                                          NaN                                                                                                                    5                                                                         NaN
# 89                                             search                                                                 yes                                                  ato.gov.au                                                                                                          NaN                                                                                                                    2                                                                         NaN
#
# [90 rows x 6 columns]

# %%
# List the DataFrame Column names.
#list(raw_df.columns.values)

# %% [markdown]
# ### Rename column names

# %%
# Rename columns that have been named inappropriately
raw_df=raw_df.rename(columns = {'Question 1 What was the purpose of your visit to the ATO Community?':'Q1 What was the purpose of your visit to the ATO Community?', 
                                'Question 2 Were you able to find what you were looking for?': 'Q2 Were you able to find what you were looking for?',
                                'Question 3 [If answered \x91Yes\x92 for Q2 ] If your visit had not been successful, what would you have done next?':'Q3 [If Q2 = Yes ] If your visit had not been successful, what would you have done next?', 
                                "Question 4 If answered \x91No\x92 for Q2] Since you didn't find what you were looking for, what are you going to do next? ":"Q4 [If Q2 = No] Since you didn't find what you were looking for, what are you going to do next?", 
                                'Question 5 How would you rate your overall experience on ATO Community?\xa0\xa0\xa0':'Q5 How would you rate your overall experience on ATO Community?'
                               })
display(raw_df.head())
# Out:
#   Q1 What was the purpose of your visit to the ATO Community? Q2 Were you able to find what you were looking for? Q3 [If Q2 = Yes ] If your visit had not been successful, what would you have done next? Q4 [If Q2 = No] Since you didn't find what you were looking for, what are you going to do next?  Q5 How would you rate your overall experience on ATO Community?                                Any other feedback?
# 0                                             search                                                          no                                                 NaN                                                                                    Call                                                                                               3                                                              NaN
# 1                                      Find out more                                                         yes                                                 Ask                                                                                     NaN                                                                                               1                If this were to be rolled out by the ATO into ...
# 2                                      Find out more                                                         yes                                                 Ask                                                                                     NaN                                                                                               2                                                              NaN
# 3                                                Ask                                                          no                                                 NaN                                                                                     Ask                                                                                               2                                                              NaN
# 4                                      Find out more                                                         yes                                          ato.gov.au                                                                                     NaN                                                                                               3                                                              NaN

# %%
# Check revised column names
list(raw_df.columns.values)
# Out:
# ['Q1 What was the purpose of your visit to the ATO Community?',
#  'Q2 Were you able to find what you were looking for?',
#  'Q3 [If Q2 = Yes ] If your visit had not been successful, what would you have done next?',
#  "Q4 [If Q2 = No] Since you didn't find what you were looking for, what are you going to do next?",
#  'Q5 How would you rate your overall experience on ATO Community?',
#  'Any other feedback?']

# %% [markdown]
# #### Remove NaN values from open text field columns to avoid type errors.

# %% [raw]
# # Variable for storing open text field column names in a LIST.
# # Note that col names must be unique or errors will occur down the track
# # Note. QUAL fields are not included here. We don't want nan-strings in the these fields. Very annoying!
# remove_nan_cols = ['* Which of the following best describes your role? (Select all that apply)']
#
# # Define function to remove NaN values from all necessary columns
# def remove_nan(dataframe, columns):
#     for item in columns:
#         dataframe[item] = dataframe[item].fillna('nan-string')
#
# remove_nan(raw_df, [remove_nan_cols])
# raw_df

# %% [markdown]
# #### Define function to check for testers identified in the open text questions.

# %%
# Variable for storing open text field column names.
# Note that col names must be unique or errors will occur down the track
open_text_cols = ['Any other feedback?']
open_text_cols
# Out:
# ['Any other feedback?']

# %%
#raw_df.head()

# %%
# Function to check for a partial string in the selected columns.
# LDC 18/5/2017: Fixed to include all testers not just those found from the last col of open_text_columns
def remove_testers(dataframe, fragment, columns):
    for i, col in enumerate(columns):
        temp = dataframe[dataframe[col].str.contains('(?i)'+fragment) == True]
        if i == 0:
            test_df = temp
        else:
            # Union merge the dataframes
            test_df = pd.merge(test_df, temp, how='outer')
       
    return test_df

testers_df = remove_testers(raw_df, 'test', open_text_cols)

# %%
# Print out the testers to check the comments are genuine tester comments.
# Extend width so that to view all columns

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
testers_df[open_text_cols]
# Out:
# Empty DataFrame
# Columns: [Any other feedback?]
# Index: []

# %%
len(raw_df)
# Out:
# 90

# %%
#raw_df.head()

# %%
# Export spreadsheet with ATO employees excluded.
raw_df.to_csv('ato-community_lithium_clean.csv',',',index=False) # export to csv without the indices
