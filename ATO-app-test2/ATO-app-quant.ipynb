# %% [markdown]
# # ATO App - Test 2

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
from IPython.display import display, HTML

import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
# %matplotlib inline

# %% [markdown]
# ## Import Beta Loop11 script

# %%
import loop11_functions as beta

# %%
# %run loop11_functions.py

# %% [markdown]
# ## Import data

# %%
clean_df = pd.read_csv('ATOapp_2_clean.csv', encoding='latin-1')

# %%
# Define sample size for future use in the script as a variable called N
N = len(clean_df)
N
# Out:
# 152

# %%
# Delare variable to store folder file location
folder = "Graphs/standard_graphs/"

# %%
list(clean_df.columns.values) # For reference later when picking out data in specific column
# Out:
# ['Unnamed: 0',
#  'Participant No.',
#  'CustomID',
#  'IP Address',
#  'Date Started',
#  'Date Completed',
#  'User Agent',
#  'Total Time Spent',
#  'Avg Time Taken',
#  'Avg Page Views',
#  '1. Task. How to use the task panel',
#  'Page Views',
#  'Time Spent',
#  'Task 1 - Onboarding',
#  'Task 1 - Page Views',
#  'Task 1 - Time Spent',
#  'Task 2 - Personalisation',
#  'Task 2 - Page Views',
#  'Task 2 - Time Spent',
#  'Task 3 - Help',
#  'Task 3 - Page Views',
#  'Task 3 - Time Spent',
#  'Task 4 - Settings',
#  'Task 4 - Page Views',
#  'Task 4 - Time Spent',
#  'Q.1 As an employee I can use this feature to record: (select all that apply)',
#  'Q.2 As a sole trader I can use this feature to record: (select all that apply)',
#  'Q.3 Where would you expect to be able to upload your information when uploading your records to your tax return? (select all that apply)',
#  'Q.3 Other, please specify',
#  'Q4 I am confident I selected the right settings to set up the app.',
# ...

# %% [markdown]
# ## Tasks and Questions

# %% [markdown]
# ### Task 1 - Onboarding

# %%
beta.task_completion_rates_adjusted_N(clean_df, ['Task 1 - Onboarding'], N, folder)
# Out:
# CONFIDENCE INTERVAL:  Task 1 - Onboarding 0.0618391604379
#              Task 1 - Onboarding (N)  Task 1 - Onboarding (%)
# Task Result
# success                        124.0                 0.815789
# fail                            28.0                 0.184211
# abandon                          NaN                      NaN

# %% [markdown]
# ### As an employee I can use this feature to record: (select all that apply)

# %%
q1 = ['Q.1 As an employee I can use this feature to record: (select all that apply)']
beta.multiple_answer(clean_df, q1, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152
# NO. ANSWERS: 292
#                                            Q.1 As an employee I can use this feature to record: (select all that apply) (N)  \
# Expenses                                                                                 125
# Trips                                                                                    105
# Income                                                                                    35
# I canât use this feature as an employee                                                 27
#
#                                            Q.1 As an employee I can use this feature to record: (select all that apply) (%)
# Expenses                                                                            0.822368
# Trips                                                                               0.690789
# Income                                                                              0.230263
# ...

# %% [markdown]
# ### As a sole trader I can use this feature to record: (select all that apply)

# %%
q2 = ['Q.2 As a sole trader I can use this feature to record: (select all that apply)']
beta.multiple_answer(clean_df, q2, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152
# NO. ANSWERS: 356
#                                              Q.2 As a sole trader I can use this feature to record: (select all that apply) (N)  \
# Expenses                                                                                   145
# Trips                                                                                      132
# Income                                                                                      71
# I canât use this feature as a sole trader                                                  8
#
#                                              Q.2 As a sole trader I can use this feature to record: (select all that apply) (%)
# Expenses                                                                              0.953947
# Trips                                                                                 0.868421
# Income                                                                                0.467105
# ...

# %% [markdown]
# ###  Where would you expect to be able to upload your information when "uploading your records to your tax return"? (select all that apply)

# %%
q3 = ['Q.3 Where would you expect to be able to upload your information when uploading your records to your tax return? (select all that apply)',]
beta.multiple_answer(clean_df, q3, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152
# NO. ANSWERS: 309
#                                             Q.3 Where would you expect to be able to upload your information when uploading your records to your tax return? (select all that apply) (N)  \
# Into my online tax return (myTax)                                                         110
# To my computer as a backup                                                                 67
# Into a third-party app like Zero/MYOB etc.                                                 63
# Into cloud storage                                                                         60
# Iâm unsure/I don't know                                                                   9
#
#                                             Q.3 Where would you expect to be able to upload your information when uploading your records to your tax return? (select all that apply) (%)
# Into my online tax return (myTax)                                                    0.723684
# ...

# %% [markdown]
# #### OTHER RESPONSES:

# %%
beta.other_responses(clean_df, 'Q.3 Other, please specify')
# Out:
# NUMBER OF RESPONSES:  9
# 'to Centrlink /DHS'
# 'to my tax agent'
# 'Facility to double check documents before they are uploaded to tax return - upload to PC/tablet for personal verification'
# '(You have spelt Xero wrong in the third option above!)'
# 'send to tax agent'
# 'excel spreadsheet + prefill report'
# 'Onto my device'
# "Don't use myob"
# 'To an excel spreadsheet so I can give it to my accountant'

# %% [markdown]
# ### Task 2 - Personalisation

# %%
beta.task_completion_rates_adjusted_N(clean_df, ['Task 2 - Personalisation'], N, folder)
# Out:
# CONFIDENCE INTERVAL:  Task 2 - Personalisation 0.0781852427386
#              Task 2 - Personalisation (N)  Task 2 - Personalisation (%)
# Task Result
# success                                83                      0.546053
# fail                                   68                      0.447368
# abandon                                 1                      0.006579

# %% [markdown]
# ### I am confident I selected the right settings to set up the app.

# %%
q4 = ['Q4 I am confident I selected the right settings to set up the app.']
beta.likert_results(clean_df, q4, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152 (Q4 I am confident I selected the right settings to set up the app.)
# TOTAL %: 1.0 (Q4 I am confident I selected the right settings to set up the app.)
#                             Q4 I am confident I selected the right settings to set up the app. (N)  \
# Agree                                                                     109
# Neither agree nor disagree                                                 31
# Disagree                                                                   12
#
#                             Q4 I am confident I selected the right settings to set up the app. (%)
# Agree                                                                0.717105
# Neither agree nor disagree                                           0.203947
# Disagree                                                             0.078947

# %% [markdown]
# ### This feature (myDeductions) can be used by: (select all that apply)

# %%
q5 = ['Q.5 This feature (myDeductions) can be used by: (select all that apply)']
beta.multiple_answer(clean_df, q5, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152
# NO. ANSWERS: 376
#                            Q.5 This feature (myDeductions) can be used by: (select all that apply) (N)  \
# Sole traders                                                             142
# Employees                                                                120
# All small business owners                                                 82
# Tax professionals                                                         26
# Iâm unsure                                                               6
#
#                            Q.5 This feature (myDeductions) can be used by: (select all that apply) (%)
# Sole traders                                                        0.934211
# Employees                                                           0.789474
# All small business owners                                           0.539474
# Tax professionals                                                   0.171053
# ...

# %% [markdown]
# ### All small business owners can use this app to upload their records to their tax return.

# %%
q6 = ['Q.6 All small business owners can use this app to upload their records to their tax return.']
beta.single_answer(clean_df, q6, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152 (Q.6 All small business owners can use this app to upload their records to their tax return.)
# TOTAL %: 1.0 (Q.6 All small business owners can use this app to upload their records to their tax return.)
#             Q.6 All small business owners can use this app to upload their records to their tax return. (N)  \
# TRUE                                                       75
# FALSE                                                      49
# I'm unsure                                                 28
#
#             Q.6 All small business owners can use this app to upload their records to their tax return. (%)
# TRUE                                                 0.493421
# FALSE                                                0.322368
# I'm unsure                                           0.184211

# %% [markdown]
# ### Task 3 - Help

# %%
beta.task_completion_rates_adjusted_N(clean_df, ['Task 3 - Help'], N, folder)
# Out:
# CONFIDENCE INTERVAL:  Task 3 - Help 0.0575456433737
#              Task 3 - Help (N)  Task 3 - Help (%)
# Task Result
# success                     23           0.151316
# fail                       124           0.815789
# abandon                      5           0.032895

# %% [markdown]
# ### It was clear where I had to go to find the information I needed.

# %%
q8 = ['Q.8. It was clear where I had to go to find the information I needed.']
beta.likert_results(clean_df, q8, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152 (Q.8. It was clear where I had to go to find the information I needed.)
# TOTAL %: 1.0 (Q.8. It was clear where I had to go to find the information I needed.)
#                             Q.8. It was clear where I had to go to find the information I needed. (N)  \
# Agree                                                                      60
# Disagree                                                                   58
# Neither agree nor disagree                                                 34
#
#                             Q.8. It was clear where I had to go to find the information I needed. (%)
# Agree                                                                0.394737
# Disagree                                                             0.381579
# Neither agree nor disagree                                           0.223684

# %% [markdown]
# ### Task 4 - Settings

# %%
beta.task_completion_rates_adjusted_N(clean_df, ['Task 4 - Settings'], N, folder)
# Out:
# CONFIDENCE INTERVAL:  Task 4 - Settings 0.0690877507451
#              Task 4 - Settings (N)  Task 4 - Settings (%)
# Task Result
# success                        113               0.743421
# fail                            36               0.236842
# abandon                          3               0.019737

# %% [markdown]
# ### I found it easy to locate the settings feature.

# %%
q9 = ['Q.9. I found it easy to locate the settings feature.']
beta.likert_results(clean_df, q9, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152 (Q.9. I found it easy to locate the settings feature.)
# TOTAL %: 1.0 (Q.9. I found it easy to locate the settings feature.)
#                             Q.9. I found it easy to locate the settings feature. (N)  \
# Agree                                                                     113
# Neither agree nor disagree                                                 20
# Disagree                                                                   19
#
#                             Q.9. I found it easy to locate the settings feature. (%)
# Agree                                                                0.743421
# Neither agree nor disagree                                           0.131579
# Disagree                                                             0.125000

# %% [markdown]
# ### I expected to find the "Personalisation" function in the settings.

# %%
q10 = ['Q.10 I expected to find the "Personalisation" function in the settings.']
beta.likert_results(clean_df, q10, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152 (Q.10 I expected to find the "Personalisation" function in the settings.)
# TOTAL %: 1.0 (Q.10 I expected to find the "Personalisation" function in the settings.)
#                             Q.10 I expected to find the "Personalisation" function in the settings. (N)  \
# Agree                                                                     126
# Neither agree nor disagree                                                 20
# Disagree                                                                    6
#
#                             Q.10 I expected to find the "Personalisation" function in the settings. (%)
# Agree                                                                0.828947
# Neither agree nor disagree                                           0.131579
# Disagree                                                             0.039474

# %% [markdown]
# ### I found the language used in the tool easy to understand.

# %%
q12= ['Q.12 I found the language used in the tool easy to understand.']
beta.likert_results(clean_df, q12, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152 (Q.12 I found the language used in the tool easy to understand.)
# TOTAL %: 1.0 (Q.12 I found the language used in the tool easy to understand.)
#                             Q.12 I found the language used in the tool easy to understand. (N)  \
# Agree                                                                     111
# Neither agree nor disagree                                                 29
# Disagree                                                                   12
#
#                             Q.12 I found the language used in the tool easy to understand. (%)
# Agree                                                                0.730263
# Neither agree nor disagree                                           0.190789
# Disagree                                                             0.078947

# %% [markdown]
# ###  On this screen, what do you understand the term "Cash flow position" to mean? (select all that apply)

# %%
q14 = ['Q.14 On this screen, what do you understand the term Cash flow position to mean? (select all that apply)']
beta.multiple_answer(clean_df, q14, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152
# NO. ANSWERS: 173
#                                                     Q.14 On this screen, what do you understand the term Cash flow position to mean? (select all that apply) (N)  \
# The balance of my recorded income less any expe...                                                101
# Balance of your business bank account                                                              50
# My taxable business income                                                                         17
# How much I can expect to earn after tax                                                             5
#
#                                                     Q.14 On this screen, what do you understand the term Cash flow position to mean? (select all that apply) (%)
# The balance of my recorded income less any expe...                                           0.664474
# Balance of your business bank account                                                        0.328947
# ...

# %% [markdown]
# #### OTHER RESPONSES:

# %%
beta.other_responses(clean_df, 'Q.14. Other, please specify',)
# Out:
# NUMBER OF RESPONSES:  10
# "Not a term I use, so I didn't really know what it meant. I gathered from the maths that it was income-expenses. But is GST included as an expense and an income?"
# "wouldn't have a clue, is it to do with wthere the business is actually making money?"
# 'Income less expenses on a cash not accruals basis which should equal cash at bank accounts'
# 'Back button did not work'
# 'a meaningless figure as this tool needs to have the aability to specify whether the expense was from cash, bank, debit card, or credit card. Then it should be able to show all 3 or 4 balances'
# 'stupid words - this tool was about deductions NOT cash'
# "Couldn't use the back button to see the required screen"
# 'Not sure'
# "I can't read the entirity of the instruction and therefore cannot answer this question"
# 'My ability to meet upcoming expenses'

# %% [markdown]
# ### Please respond to the following statement: As a business I would find the "Cash flow position" feature useful.

# %%
q15= ['Q.15 As a business I would find the Cash flow position feature useful.']
beta.likert_results(clean_df, q15, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 151 (Q.15 As a business I would find the Cash flow position feature useful.)
# TOTAL %: 1.0 (Q.15 As a business I would find the Cash flow position feature useful.)
#                               Q.15 As a business I would find the Cash flow position feature useful. (N)  \
# Agree                                                                        73
# Disagree                                                                     33
# Neither agree nor disagree                                                   30
# I'm not operating a business                                                 15
#
#                               Q.15 As a business I would find the Cash flow position feature useful. (%)
# Agree                                                                  0.483444
# Disagree                                                               0.218543
# Neither agree nor disagree                                             0.198675
# ...

# %% [markdown]
# ### If you are a sole trader, do you use your own name as your business name?

# %%
q16 = ['Q.16 If you are a sole trader, do you use your own name as your business name?']
beta.single_answer(clean_df, q16, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152 (Q.16 If you are a sole trader, do you use your own name as your business name?)
# TOTAL %: 1.0 (Q.16 If you are a sole trader, do you use your own name as your business name?)
#                                         Q.16 If you are a sole trader, do you use your own name as your business name? (N)  \
# Not applicable (I'm not a sole trader)                                                 63
# Yes                                                                                    50
# No                                                                                     39
#
#                                         Q.16 If you are a sole trader, do you use your own name as your business name? (%)
# Not applicable (I'm not a sole trader)                                           0.414474
# Yes                                                                              0.328947
# ...

# %% [markdown]
# #### REMOVE NON SOLE TRADERS FROM THE STATS FOR Q.16

# %%
# Remove N/A responses into separate DataFrame
st_q = 'Q.16 If you are a sole trader, do you use your own name as your business name?'
sole_traders_df = clean_df[clean_df[st_q].str.contains("(?i)Not applicable") == False]

beta.single_answer(sole_traders_df, q16, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 89 (Q.16 If you are a sole trader, do you use your own name as your business name?)
# TOTAL %: 1.0 (Q.16 If you are a sole trader, do you use your own name as your business name?)
#      Q.16 If you are a sole trader, do you use your own name as your business name? (N)  \
# Yes                                                 50
# No                                                  39
#
#      Q.16 If you are a sole trader, do you use your own name as your business name? (%)
# Yes                                           0.561798
# No                                            0.438202

# %% [markdown]
# ## Demographic Questions

# %%
ato_employees = ['Q.18 Are you an ATO employee?']
beta.single_answer(clean_df, ato_employees, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152 (Q.18 Are you an ATO employee?)
# TOTAL %: 1.0 (Q.18 Are you an ATO employee?)
#      Q.18 Are you an ATO employee? (N)  Q.18 Are you an ATO employee? (%)
# No                                 131                           0.861842
# Yes                                 21                           0.138158

# %%
age_groups = ['Q.20 Which age group do you belong to?']
beta.single_answer(clean_df, age_groups, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 147 (Q.20 Which age group do you belong to?)
# TOTAL %: 1.0 (Q.20 Which age group do you belong to?)
#                Q.20 Which age group do you belong to? (N)  \
# 46-65                                                  73
# 26-45                                                  58
# Older than 65                                          11
# 18-25                                                   5
#
#                Q.20 Which age group do you belong to? (%)
# 46-65                                            0.496599
# 26-45                                            0.394558
# Older than 65                                    0.074830
# 18-25                                            0.034014

# %%
groups = ['Q.19 Which of the following best describes your role? (select all that apply)']
beta.multiple_answer(clean_df, groups, beta.grapher_horizontal, folder)
# Out:
# SAMPLE SIZE: 152
# NO. ANSWERS: 228
#                            Q.19 Which of the following best describes your role? (select all that apply) (N)  \
# Individual taxpayer                                                       67
# Small business                                                            60
# Sole trader/self-employed                                                 53
# Tax professional                                                          33
# Self-managed Superfund                                                    10
# Not-for-profit                                                             4
# Large business                                                             1
#
#                            Q.19 Which of the following best describes your role? (select all that apply) (%)
# Individual taxpayer                                                 0.440789
# Small business                                                      0.394737
# ...

# %% [markdown]
# #### OTHER RESPONSES:

# %%
beta.other_responses(clean_df, 'Q.19 Other, please specify')
# Out:
# NUMBER OF RESPONSES:  8
# 'BAS Agent'
# 'Business Advisor'
# 'Bookkeeper'
# 'Employee'
# 'Tax Accountant for an Industrial company'
# 'Director of a small company'
# 'ATO employee'
# 'IT profressional looking at your approach to user research'
